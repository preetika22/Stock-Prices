# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.87-py2.py3-none-any.whl (29 kB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\preetika\anaconda3\lib\site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: requests>=2.26 in c:\users\preetika\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\preetika\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\preetika\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\preetika\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\preetika\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\preetika\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\preetika\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\preetika\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\preetika\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\preetika\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\preetika\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.11 yfinance-0.1.87

# %%
import pandas as pd
import numpy as np
import yfinance
import matplotlib.pyplot as plt
from scipy.stats import skew,kurtosis,norm,skewtest,kurtosistest
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf

# %%
name = 'Food'
ticker = yfinance.Ticker(name)
df = ticker.history(interval="1d",start="2015-03-15",end="2020-09-10")
x = df['Close']

# %%
returns = x.pct_change(1).dropna()

# %%
plt.hist(returns,bins="rice",label="Daily close price")
plt.legend()
plt.show()

# %%
plt.boxplot(returns,labels=["Daily close price"])
plt.show()

# %%
np.mean(returns)
# Out:
# 3577.5357211346204

# %%
np.quantile(returns,0.5)
# Out:
# 0.0

# %%
t = np.linspace(0.01,0.99,1000)
q1 = np.quantile(returns,t)
q2 = norm.ppf(t,loc=np.mean(returns),scale=np.std(returns))
plt.plot(q1,q2)
plt.plot([min(q1),max(q1)],[min(q2),max(q2)])
plt.xlim((min(q1),max(q1)))
plt.ylim((min(q2),max(q2)))
plt.xlabel("Daily returns")
plt.ylabel("Normal distribution")
plt.show()

# %%
plt.plot(returns)
plt.xlabel("Time")
plt.ylabel("Daily returns")
plt.show()

# %%
plt.plot(returns.rolling(20).std())
plt.xlabel("Time")
plt.ylabel("20-days rolling standard deviation")
plt.show()
